# %% [markdown]
# * Estimativa populacional segundo ano, sexo, faixa etária e local de residência.
# * Município de São Paulo
# * População por Dist Adm (DA) e Faixa Etária
# * Período:2018

# %%
# https://drive.google.com/drive/folders/18MjRzqdVn7dRQTc5I4MVJl9gE_3uZKjI

# %%
import pandas as pd

# ID do arquivo no Google Drive
file_id = "1YsiJbfUVWRJhbXRMgJAZC7Q79mSC0HrS"

# Link direto para download
download_url = f"https://drive.google.com/uc?export=download&id={file_id}"

# Ler o CSV pulando as 3 primeiras linhas
df = pd.read_csv(
    download_url,
    encoding="latin1",   # evita o erro de acentuação
    sep=';',             # muito comum em arquivos PT-BR; troque para ',' se não for o caso
    skiprows=4           # pula as 4 primeiras linhas (dados começam na 4ª)
)
# copiar df
df2018 = df.copy()

#coluna ano
df2018["ano"] = 2018
# Ver as primeiras linhas
df2018.head()
# Out:
#   Distrito Admin residência 50 - 59 60 - 69 Total   ano
# 0                 Água Rasa       -       -     -  2018
# 1         Alto de Pinheiros       -       -     -  2018
# 2                Anhanguera       -       -     -  2018
# 3                Aricanduva       -       -     -  2018
# 4               Artur Alvim       -       -     -  2018

# %%
# import pandas as pd
# https://drive.google.com/file/d/1XBJUhRDBb5-NGF8zfFLE9PC6X2XURD4N/view?usp=sharing

# ID do arquivo no Google Drive
file_id = "1XBJUhRDBb5-NGF8zfFLE9PC6X2XURD4N"

# Link direto para download
download_url = f"https://drive.google.com/uc?export=download&id={file_id}"

# Ler o CSV pulando as 3 primeiras linhas
df = pd.read_csv(
    download_url,
    encoding="latin1",   # evita o erro de acentuação
    sep=';',             # muito comum em arquivos PT-BR; troque para ',' se não for o caso
    skiprows=3           # pula as 4 primeiras linhas (dados começam na 4ª)
)
# copiar df
df2019 = df.copy()

# coluna ano
df2019["ano"] = 2019
# Ver as primeiras linhas

# rename "Dist Adm (DA)"
df2019 = df2019.rename(columns={"Dist Adm (DA)":"Distrito Admin residência"})
display(df2019.head())
display(df2019.tail())
# Out:
#   Distrito Admin residência 00 a 04 05 a 09 10 a 14 15 a 19 20 a 24 25 a 29  \
# 0                 Água Rasa    3895    4474    4273    4374    5226    6072
# 1         Alto de Pinheiros    1276    1530    1723    1724    2080    2553
# 2                Anhanguera    4382    4679    5331    5931    7350    7393
# 3                Aricanduva    4374    4992    5296    5676    6779    7058
# 4               Artur Alvim    4845    5566    5960    6161    7416    7872
#
#   30 a 34 35 a 39 40 a 44 45 a 49 50 a 54 55 a 59 60 a 64 65 a 69 70 a 74  \
# 0    6306    6606    6925    6095    5974    6091    5501    4515    3729
# 1    2668    2779    3148    2760    2836    3037    2741    2470    2155
# 2    6282    5652    5733    5507    4973    3661    2533    1625     960
# 3    6997    7007    6842    6366    6166    5571    4970    4027    3369
# 4    7922    8244    8180    7027    6258    5825    5151    4379    3533
#
#   75 e mais  Total   ano
# 0      7072  87128  2019
# 1      4307  39787  2019
# 2       981  72973  2019
# 3      5416  90906  2019
# 4      5175  99514  2019
#                             Distrito Admin residência 00 a 04 05 a 09 10 a 14  \
# 94                                      Vila Prudente    4747    5463    5726
# 95                                         Vila Sônia    6602    7495    7264
# 96                                           Ignorado       -       -       -
# 97                                              Total  634437  710419  725388
# 98  Fonte: Estimativas populacionais - Fundação SE...     NaN     NaN     NaN
#
#    15 a 19 20 a 24 25 a 29 30 a 34 35 a 39 40 a 44 45 a 49 50 a 54 55 a 59  \
# 94    5714    6898    7929    8571    8759    8520    7323    7205    7088
# 95    7403    8499    9538    9792   10201   10161    8652    7802    6822
# 96       -       -       -       -       -       -       -       -       -
# 97  759805  891828  940199  930247  941813  924576  805794  740740  655050
# 98     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    60 a 64 65 a 69 70 a 74 75 e mais     Total   ano
# 94    6308    5100    4087      7199    106637  2019
# 95    5993    4892    3870      5877    120863  2019
# 96       -       -       -         -         -  2019
# 97  561935  440976  336026    509882  11509115  2019
# 98     NaN     NaN     NaN       NaN       NaN  2019

# %%
import pandas as pd

# https://drive.google.com/file/d/19oXY4agxNSTvPInxZcPJru6SclQ9tb_J/view?usp=drive_link

# ID do arquivo no Google Drive
file_id = "19oXY4agxNSTvPInxZcPJru6SclQ9tb_J"

# Link direto para download
download_url = f"https://drive.google.com/uc?export=download&id={file_id}"

# Ler o CSV pulando as 3 primeiras linhas
df = pd.read_csv(
    download_url,
    encoding="latin1",   # evita o erro de acentuação
    sep=';',             # muito comum em arquivos PT-BR; troque para ',' se não for o caso
    skiprows=3           # pula as 4 primeiras linhas (dados começam na 4ª)
)
# copiar df
df2020 = df.copy()

# coluna ano
df2020["ano"] = 2020
# Ver as primeiras linhas

# rename "Dist Adm (DA)"
df2020 = df2020.rename(columns={"Dist Adm (DA)":"Distrito Admin residência"})
display(df2020.head())
display(df2020.tail())
# Out:
#   Distrito Admin residência 00 a 04 05 a 09 10 a 14 15 a 19 20 a 24 25 a 29  \
# 0                 Água Rasa    3820    4516    4220    4341    5071    5927
# 1         Alto de Pinheiros    1236    1465    1691    1693    1967    2458
# 2                Anhanguera    4392    4522    5190    5817    7341    7517
# 3                Aricanduva    4307    4900    5154    5570    6707    6927
# 4               Artur Alvim    4727    5393    5803    5989    7239    7644
#
#   30 a 34 35 a 39 40 a 44 45 a 49 50 a 54 55 a 59 60 a 64 65 a 69 70 a 74  \
# 0    6234    6552    7038    6115    5860    6159    5644    4642    3814
# 1    2622    2677    3174    2719    2721    3064    2740    2504    2177
# 2    6412    5668    5666    5516    5181    3883    2697    1775    1033
# 3    6933    7066    6835    6337    6204    5623    5107    4115    3441
# 4    7719    8184    8213    7088    6184    5859    5168    4459    3596
#
#   75 e mais  Total   ano
# 0      7178  87131  2020
# 1      4387  39295  2020
# 2      1048  73658  2020
# 3      5596  90822  2020
# 4      5327  98592  2020
#                             Distrito Admin residência 00 a 04 05 a 09 10 a 14  \
# 94                                      Vila Prudente    4675    5374    5688
# 95                                         Vila Sônia    6513    7575    7207
# 96                                           Ignorado       -       -       -
# 97                                              Total  623870  702282  708086
# 98  Fonte: Estimativas populacionais - Fundação SE...     NaN     NaN     NaN
#
#    15 a 19 20 a 24 25 a 29 30 a 34 35 a 39 40 a 44 45 a 49 50 a 54 55 a 59  \
# 94    5642    6733    7651    8478    8819    8698    7313    7113    7174
# 95    7441    8332    9355    9698   10270   10416    8818    7966    6967
# 96       -       -       -       -       -       -       -       -       -
# 97  747965  877626  922406  917855  943864  933886  809656  746147  665302
# 98     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    60 a 64 65 a 69 70 a 74 75 e mais     Total   ano
# 94    6478    5278    4176      7374    106664  2020
# 95    6174    5085    4041      6115    121973  2020
# 96       -       -       -         -         -  2020
# 97  577468  457901  347779    525507  11507600  2020
# 98     NaN     NaN     NaN       NaN       NaN  2020

# %%
import pandas as pd

# https://drive.google.com/file/d/17jBVRJPXeXGgJtn1JYVjRC6JxD6I2MTQ/view?usp=sharing

# ID do arquivo no Google Drive
file_id = "17jBVRJPXeXGgJtn1JYVjRC6JxD6I2MTQ"

# Link direto para download
download_url = f"https://drive.google.com/uc?export=download&id={file_id}"

# Ler o CSV pulando as 3 primeiras linhas
df = pd.read_csv(
    download_url,
    encoding="latin1",   # evita o erro de acentuação
    sep=';',             # muito comum em arquivos PT-BR; troque para ',' se não for o caso
    skiprows=3           # pula as 4 primeiras linhas (dados começam na 4ª)
)
# copiar df
df2021 = df.copy()

# coluna ano
df2021["ano"] = 2021
# Ver as primeiras linhas

# rename "Dist Adm (DA)"
df2021 = df2021.rename(columns={"Dist Adm (DA)":"Distrito Admin residência"})
display(df2021.head())
display(df2021.tail())
# Out:
#   Distrito Admin residência 00 a 04 05 a 09 10 a 14 15 a 19 20 a 24 25 a 29  \
# 0                 Água Rasa    3739    4432    4197    4306    5011    5717
# 1         Alto de Pinheiros    1191    1423    1594    1670    1926    2315
# 2                Anhanguera    4383    4559    4952    5696    7178    7450
# 3                Aricanduva    4237    4827    4984    5451    6556    6817
# 4               Artur Alvim    4588    5263    5535    5858    7002    7416
#
#   30 a 34 35 a 39 40 a 44 45 a 49 50 a 54 55 a 59 60 a 64 65 a 69 70 a 74  \
# 0    6110    6554    7005    6153    5866    6066    5751    4794    3893
# 1    2535    2667    3067    2722    2680    2956    2789    2522    2193
# 2    6554    5868    5721    5424    5206    4087    2898    1913    1127
# 3    6833    7084    6925    6270    6163    5687    5197    4253    3492
# 4    7520    8067    8181    7046    6226    5812    5235    4502    3633
#
#   75 e mais  Total   ano
# 0      7257  86851  2021
# 1      4426  38676  2021
# 2      1124  74140  2021
# 3      5721  90497  2021
# 4      5422  97306  2021
#                             Distrito Admin residência 00 a 04 05 a 09 10 a 14  \
# 94                                      Vila Prudente    4600    5302    5516
# 95                                         Vila Sônia    6416    7500    7179
# 96                                           Ignorado       -       -       -
# 97                                              Total  611941  692481  689445
# 98  Fonte: Estimativas populacionais - Fundação SE...     NaN     NaN     NaN
#
#    15 a 19 20 a 24 25 a 29 30 a 34 35 a 39 40 a 44 45 a 49 50 a 54 55 a 59  \
# 94    5642    6634    7432    8228    8848    8808    7404    7102    7127
# 95    7425    8336    9111    9566   10322   10551    8975    8123    7166
# 96       -       -       -       -       -       -       -       -       -
# 97  734449  861463  902662  903338  943527  940904  811477  749690  674003
# 98     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    60 a 64 65 a 69 70 a 74 75 e mais     Total   ano
# 94    6616    5462    4297      7502    106520  2021
# 95    6371    5285    4184      6358    122868  2021
# 96       -       -       -         -         -  2021
# 97  591928  474272  359030    540290  11480900  2021
# 98     NaN     NaN     NaN       NaN       NaN  2021

# %%
import pandas as pd

# https://drive.google.com/file/d/1ueTy_DAbcwBcLQiBx3XW5pJYLRDZwmtI/view?usp=sharing

# ID do arquivo no Google Drive
file_id = "1ueTy_DAbcwBcLQiBx3XW5pJYLRDZwmtI"

# Link direto para download
download_url = f"https://drive.google.com/uc?export=download&id={file_id}"

# Ler o CSV pulando as 3 primeiras linhas
df = pd.read_csv(
    download_url,
    encoding="latin1",   # evita o erro de acentuação
    sep=';',             # muito comum em arquivos PT-BR; troque para ',' se não for o caso
    skiprows=3           # pula as 4 primeiras linhas (dados começam na 4ª)
)
# copiar df
df2022 = df.copy()

# coluna ano
df2022["ano"] = 2022
# Ver as primeiras linhas

# rename "Dist Adm (DA)"
df2022 = df2022.rename(columns={"Dist Adm (DA)":"Distrito Admin residência"})
display(df2022.head())
display(df2022.tail())
# Out:
#   Distrito Admin residência 00 a 04 05 a 09 10 a 14 15 a 19 20 a 24 25 a 29  \
# 0                 Água Rasa    3653    4346    4168    4267    4948    5509
# 1         Alto de Pinheiros    1148    1381    1502    1648    1887    2179
# 2                Anhanguera    4387    4605    4737    5587    7033    7401
# 3                Aricanduva    4155    4745    4810    5323    6397    6696
# 4               Artur Alvim    4448    5130    5272    5723    6767    7189
#
#   30 a 34 35 a 39 40 a 44 45 a 49 50 a 54 55 a 59 60 a 64 65 a 69 70 a 74  \
# 0    5980    6546    6974    6187    5866    5969    5850    4942    3968
# 1    2449    2656    2966    2722    2638    2851    2838    2538    2208
# 2    6708    6090    5788    5345    5239    4311    3121    2066    1233
# 3    6715    7090    6998    6193    6111    5739    5273    4386    3531
# 4    7314    7940    8135    6999    6261    5757    5295    4536    3666
#
#   75 e mais  Total   ano
# 0      7331  86504  2022
# 1      4457  38068  2022
# 2      1209  74860  2022
# 3      5836  89998  2022
# 4      5515  95947  2022
#                             Distrito Admin residência 00 a 04 05 a 09 10 a 14  \
# 94                                      Vila Prudente    4525    5231    5343
# 95                                         Vila Sônia    6316    7421    7146
# 96                                           Ignorado       -       -       -
# 97                                              Total  599859  682361  670849
# 98  Fonte: Estimativas populacionais - Fundação SE...     NaN     NaN     NaN
#
#    15 a 19 20 a 24 25 a 29 30 a 34 35 a 39 40 a 44 45 a 49 50 a 54 55 a 59  \
# 94    5637    6531    7214    7979    8867    8911    7496    7087    7073
# 95    7404    8336    8863    9422   10351   10688    9126    8279    7362
# 96       -       -       -       -       -       -       -       -       -
# 97  720699  845036  882758  888461  942560  947340  812759  752751  682363
# 98     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    60 a 64 65 a 69 70 a 74 75 e mais     Total   ano
# 94    6755    5649    4415      7634    106347  2022
# 95    6570    5489    4324      6604    123701  2022
# 96       -       -       -         -         -  2022
# 97  606345  490900  370402    555166  11450609  2022
# 98     NaN     NaN     NaN       NaN       NaN  2022

# %%
import pandas as pd

# https://drive.google.com/file/d/1M8A1yXCtg10QsFefLS-tp33d-7P6LRRK/view?usp=sharing

# ID do arquivo no Google Drive
file_id = "1M8A1yXCtg10QsFefLS-tp33d-7P6LRRK"

# Link direto para download
download_url = f"https://drive.google.com/uc?export=download&id={file_id}"

# Ler o CSV pulando as 3 primeiras linhas
df = pd.read_csv(
    download_url,
    encoding="latin1",   # evita o erro de acentuação
    sep=';',             # muito comum em arquivos PT-BR; troque para ',' se não for o caso
    skiprows=3           # pula as 4 primeiras linhas (dados começam na 4ª)
)
# copiar df
df2023 = df.copy()

# coluna ano
df2023["ano"] = 2023
# Ver as primeiras linhas

# rename "Dist Adm (DA)"
df2023 = df2023.rename(columns={"Dist Adm (DA)":"Distrito Admin residência"})
display(df2023.head())
display(df2023.tail())
# Out:
#   Distrito Admin residência 00 a 04 05 a 09 10 a 14 15 a 19 20 a 24 25 a 29  \
# 0                 Água Rasa    3577    4267    4143    4236    4894    5318
# 1         Alto de Pinheiros    1107    1341    1418    1628    1847    2054
# 2                Anhanguera    4376    4638    4516    5465    6871    7330
# 3                Aricanduva    4088    4679    4652    5210    6258    6594
# 4               Artur Alvim    4326    5014    5033    5601    6552    6981
#
#   30 a 34 35 a 39 40 a 44 45 a 49 50 a 54 55 a 59 60 a 64 65 a 69 70 a 74  \
# 0    5855    6551    6944    6229    5873    5879    5960    5105    4050
# 1    2369    2649    2871    2724    2598    2753    2892    2558    2226
# 2    6841    6302    5841    5251    5259    4531    3348    2221    1342
# 3    6616    7112    7098    6131    6074    5804    5368    4539    3581
# 4    7127    7829    8115    6965    6307    5716    5365    4583    3707
#
#   75 e mais  Total   ano
# 0      7416  86297  2023
# 1      4497  37532  2023
# 2      1296  75428  2023
# 3      5969  89773  2023
# 4      5619  94840  2023
#                             Distrito Admin residência 00 a 04 05 a 09 10 a 14  \
# 94                                      Vila Prudente    4456    5165    5182
# 95                                         Vila Sônia    6216    7347    7113
# 96                                           Ignorado       -       -       -
# 97                                              Total  588307  672710  653067
# 98  Fonte: Estimativas populacionais - Fundação SE...     NaN     NaN     NaN
#
#    15 a 19 20 a 24 25 a 29 30 a 34 35 a 39 40 a 44 45 a 49 50 a 54 55 a 59  \
# 94    5637    6438    7011    7742    8883    9037    7593    7078    7025
# 95    7384    8334    8624    9277   10391   10823    9282    8438    7565
# 96       -       -       -       -       -       -       -       -       -
# 97  707547  829320  863704  874249  942044  954280  814433  756184  691157
# 98     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    60 a 64 65 a 69 70 a 74 75 e mais     Total   ano
# 94    6902    5849    4544      7771    106313  2023
# 95    6775    5701    4472      6863    124605  2023
# 96       -       -       -         -         -  2023
# 97  621411  508354  382313    570785  11429865  2023
# 98     NaN     NaN     NaN       NaN       NaN  2023

# %%
import pandas as pd

# https://drive.google.com/file/d/1x9Akwi3D8eLQnfCX084Kgv_I1fAUJS1c/view?usp=sharing

# ID do arquivo no Google Drive
file_id = "1x9Akwi3D8eLQnfCX084Kgv_I1fAUJS1c"

# Link direto para download
download_url = f"https://drive.google.com/uc?export=download&id={file_id}"

# Ler o CSV pulando as 3 primeiras linhas
df = pd.read_csv(
    download_url,
    encoding="latin1",   # evita o erro de acentuação
    sep=';',             # muito comum em arquivos PT-BR; troque para ',' se não for o caso
    skiprows=3           # pula as 4 primeiras linhas (dados começam na 4ª)
)
# copiar df
df2024 = df.copy()

# coluna ano
df2024["ano"] = 2024
# Ver as primeiras linhas

# rename "Dist Adm (DA)"
df2024 = df2024.rename(columns={"Dist Adm (DA)":"Distrito Admin residência"})
display(df2024.head())
display(df2024.tail())
# Out:
#   Distrito Admin residência 00 a 04 05 a 09 10 a 14 15 a 19 20 a 24 25 a 29  \
# 0                 Água Rasa    3498    4182    4114    4197    4832    5126
# 1         Alto de Pinheiros    1067    1303    1336    1608    1809    1934
# 2                Anhanguera    4359    4665    4295    5336    6699    7254
# 3                Aricanduva    4021    4609    4495    5097    6121    6486
# 4               Artur Alvim    4199    4892    4794    5472    6336    6771
#
#   30 a 34 35 a 39 40 a 44 45 a 49 50 a 54 55 a 59 60 a 64 65 a 69 70 a 74  \
# 0    5727    6545    6897    6262    5876    5785    6065    5266    4131
# 1    2287    2639    2775    2725    2558    2653    2941    2573    2242
# 2    6966    6509    5884    5150    5272    4754    3591    2387    1459
# 3    6508    7122    7192    6064    6032    5868    5459    4690    3632
# 4    6932    7710    8076    6921    6348    5665    5432    4623    3743
#
#   75 e mais  Total   ano
# 0      7490  85993  2024
# 1      4537  36987  2024
# 2      1387  75967  2024
# 3      6103  89499  2024
# 4      5720  93634  2024
#                             Distrito Admin residência 00 a 04 05 a 09 10 a 14  \
# 94                                      Vila Prudente    4384    5096    5016
# 95                                         Vila Sônia    6118    7266    7069
# 96                                           Ignorado       -       -       -
# 97                                              Total  576252  662348  634942
# 98  Fonte: Estimativas populacionais - Fundação SE...     NaN     NaN     NaN
#
#    15 a 19 20 a 24 25 a 29 30 a 34 35 a 39 40 a 44 45 a 49 50 a 54 55 a 59  \
# 94    5630    6339    6805    7497    8899    9142    7685    7060    6970
# 95    7355    8325    8383    9122   10418   10945    9430    8589    7765
# 96       -       -       -       -       -       -       -       -       -
# 97  693748  812855  843982  859164  940322  960039  815065  758661  699168
# 98     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    60 a 64 65 a 69 70 a 74 75 e mais     Total   ano
# 94    7042    6050    4670      7902    106187  2024
# 95    6976    5915    4619      7121    125416  2024
# 96       -       -       -         -         -  2024
# 97  636035  525755  394102    586152  11398590  2024
# 98     NaN     NaN     NaN       NaN       NaN  2024

# %%
df_anos = pd.concat([df2018,df2019,df2020,df2021,df2022,df2023,df2024])

# rename "Dist Adm (DA)"
df_anos = df_anos.rename(columns={"Dist Adm (DA)":"Distrito Admin residência"})
display(df_anos.head())
display(df_anos.tail())
# Out:
#   Distrito Admin residência 50 - 59 60 - 69 Total     ano  \
# 0                 Água Rasa       -       -     -  2018.0
# 1         Alto de Pinheiros       -       -     -  2018.0
# 2                Anhanguera       -       -     -  2018.0
# 3                Aricanduva       -       -     -  2018.0
# 4               Artur Alvim       -       -     -  2018.0
#
#   Distrito Admin residência 00 a 04 05 a 09 10 a 14 15 a 19  ... 30 a 34  \
# 0                       NaN     NaN     NaN     NaN     NaN  ...     NaN
# 1                       NaN     NaN     NaN     NaN     NaN  ...     NaN
# 2                       NaN     NaN     NaN     NaN     NaN  ...     NaN
# 3                       NaN     NaN     NaN     NaN     NaN  ...     NaN
# 4                       NaN     NaN     NaN     NaN     NaN  ...     NaN
#
#   35 a 39 40 a 44 45 a 49 50 a 54 55 a 59 60 a 64 65 a 69 70 a 74 75 e mais
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN       NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN       NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN       NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN       NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN       NaN
#
# [5 rows x 22 columns]
#                             Distrito Admin residência 50 - 59 60 - 69  \
# 94                                      Vila Prudente     NaN     NaN
# 95                                         Vila Sônia     NaN     NaN
# 96                                           Ignorado     NaN     NaN
# 97                                              Total     NaN     NaN
# 98  Fonte: Estimativas populacionais - Fundação SE...     NaN     NaN
#
#        Total     ano Distrito Admin residência 00 a 04 05 a 09 10 a 14  \
# 94    106187  2024.0                       NaN    4384    5096    5016
# 95    125416  2024.0                       NaN    6118    7266    7069
# 96         -  2024.0                       NaN       -       -       -
# 97  11398590  2024.0                       NaN  576252  662348  634942
# 98       NaN  2024.0                       NaN     NaN     NaN     NaN
#
#    15 a 19  ... 30 a 34 35 a 39 40 a 44 45 a 49 50 a 54 55 a 59 60 a 64  \
# 94    5630  ...    7497    8899    9142    7685    7060    6970    7042
# 95    7355  ...    9122   10418   10945    9430    8589    7765    6976
# 96       -  ...       -       -       -       -       -       -       -
# 97  693748  ...  859164  940322  960039  815065  758661  699168  636035
# 98     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    65 a 69 70 a 74 75 e mais
# 94    6050    4670      7902
# 95    5915    4619      7121
# 96       -       -         -
# 97  525755  394102    586152
# 98     NaN     NaN       NaN
#
# [5 rows x 22 columns]
